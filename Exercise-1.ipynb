# %%
ice_cream_rating = 9
sleeping_rating = 10

# %%
first_name = input('Enter your first name:')
last_name = input('Enter your last name:')
my_name = first_name + ' ' + last_name
# Out:
# Enter your first name: Coleen
# Enter your last name: Crisostomo

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
print(type(ice_cream_rating))
print(type(first_name))
print(type(happiness_rating))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# The data types make sense and are not different than expected.

# %%
print('My name is', first_name, 'and I give eating ice cream a score of', ice_cream_rating, 'out of 10!', '\nI am', my_name, 'and my sleeping enjoyment rating is ', sleeping_rating, '/ 10!', '\nBased on the factors above, my happiness rating is', happiness_rating, 'out of 10, or', happiness_rating / 10 * 100, '%!')
# Out:
# My name is Coleen and I give eating ice cream a score of 9 out of 10!
# I am Coleen Crisostomo and my sleeping enjoyment rating is  10 / 10!
# Based on the factors above, my happiness rating is 9.5 out of 10, or 95.0 %!
